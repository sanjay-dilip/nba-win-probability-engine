# %% [markdown]
# # 01 - Data Exploration
#
# Explore the sample datasets for the NBA Win Probability Engine.
# No models are trained in this build.

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parent
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src import config
from src.utils import load_csv

# %%
games = load_csv(config.SAMPLE_GAMES_PATH)
pregame = load_csv(config.SAMPLE_PREGAME_FEATURES_PATH)
live = load_csv(config.SAMPLE_LIVE_FEATURES_PATH)
predictions = load_csv(config.SAMPLE_PREDICTIONS_PATH)

games.head()
# Out:
#            game_id   season   game_date        home_team  \
# 0  SAMPLE_GAME_001  2024-25  2024-11-12   Boston Celtics
# 1  SAMPLE_GAME_002  2024-25  2024-11-13   Denver Nuggets
# 2  SAMPLE_GAME_003  2024-25  2024-11-15  Milwaukee Bucks
#
#                away_team  home_team_id  away_team_id status game_type
# 0             Miami Heat    1610612738    1610612748  Final   regular
# 1  Golden State Warriors    1610612743    1610612744  Final   regular
# 2     Philadelphia 76ers    1610612749    1610612755  Final   regular

# %%
pregame.describe()
# Out:
#        home_win_pct  away_win_pct  win_pct_diff  home_net_rating  \
# count      3.000000      3.000000      3.000000         3.000000
# mean       0.656333      0.570667      0.085667         5.166667
# std        0.085337      0.086408      0.118023         2.371357
# min        0.583000      0.500000     -0.031000         3.200000
# 25%        0.609500      0.522500      0.026000         3.850000
# 50%        0.636000      0.545000      0.083000         4.500000
# 75%        0.693000      0.606000      0.144000         6.150000
# max        0.750000      0.667000      0.205000         7.800000
#
#        away_net_rating  net_rating_diff  home_rest_days  away_rest_days  \
# count         3.000000         3.000000             3.0        3.000000
# mean          2.233333         2.933333             2.0        1.333333
# std           2.514624         3.601851             1.0        0.577350
# min           0.400000        -0.600000             1.0        1.000000
# ...
