# %% [markdown]
# # 02 - Model Experimentation (Placeholder)
#
# This notebook is reserved for future modeling work.
# No models are trained in this build.
#
# Planned: baseline logistic regression and XGBoost for pre-game and live
# win probability, evaluated with accuracy, ROC-AUC, log loss, and Brier score.

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parent
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src import config
from src.utils import load_csv

# Placeholder: load features to be used for future experiments.
pregame = load_csv(config.SAMPLE_PREGAME_FEATURES_PATH)
pregame.head()
